# %% [markdown]
# # Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %% [markdown]
# # Import & view data

# %%
eval = pd.read_csv('./data/evaluation_data.csv')
train = pd.read_csv('./data/training_data.csv')

# convert to parquet for faster loading in the future
eval.to_parquet('./data/evaluation_data.parquet')
train.to_parquet('./data/training_data.parquet')
# Out:
# c:\Users\3alen\anaconda3\Lib\site-packages\pyarrow\pandas_compat.py:373: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):

# %%
print(eval.shape)
eval.head()
# Out:
# (12604600, 69)
#    distance_05  customer_digital_activity_04  customer_spend_01  \
# 0     1.621171                           NaN           112.3340
# 1     2.441944                           NaN           112.3340
# 2     2.438082                           NaN           112.3340
# 3     2.072182                           NaN           112.3340
# 4     2.380853                           NaN           302.7925
#
#    customer_industry_spend_01  customer_industry_spend_02  \
# 0                     80.5525                         9.0
# 1                         NaN                         NaN
# 2                     71.1925                         3.0
# 3                         NaN                         NaN
# 4                         NaN                         NaN
#
#    customer_industry_spend_03  customer_industry_spend_04  \
# 0                      966.63                        12.0
# 1                         NaN                         NaN
# ...

# %%
print(train.shape)
train.head()
# Out:
# (12229978, 71)
#    ind_recommended  activation  customer_digital_activity_04  \
# 0                0           0                           NaN
# 1                0           0                           NaN
# 2                0           0                           NaN
# 3                0           0                           NaN
# 4                1           0                           NaN
#
#    customer_spend_01  customer_industry_spend_01  customer_industry_spend_02  \
# 0         107.215862                   26.686594                        74.0
# 1          35.552000                   50.928261                         3.0
# 2          31.623103                   48.837872                        19.0
# 3         112.277391                         NaN                         NaN
# 4         448.427273                         NaN                         NaN
#
#    customer_industry_spend_03  customer_industry_spend_04  \
# ...

# %% [markdown]
# NaN values spread across different columns, have to think about how to deal with this without losing too much data.
